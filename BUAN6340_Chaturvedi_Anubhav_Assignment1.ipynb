# %%
import pandas as pd

# %% [markdown]
# ### Github Link: https://github.com/anubhav582/Python_BUAN6340

# %% [markdown]
# ### Q1 Load in the appropriate csv file as a pandas dataframe (batting.csv)

# %%
df =  pd.read_csv('Batting.csv')
df.head()
# Out:
#     playerID nameFirst     nameLast  birthYear  yearID  stint teamID lgID   G  \
# 0  abercda01     Frank  Abercrombie       1850    1871      1    TRO  NaN   1
# 1   addybo01       Bob         Addy       1842    1871      1    RC1  NaN  25
# 2  allisar01       Art      Allison       1849    1871      1    CL1  NaN  29
# 3  allisdo01      Doug      Allison       1846    1871      1    WS3  NaN  27
# 4  ansonca01       Cap        Anson       1852    1871      1    RC1  NaN  25
#
#     AB  ...    RBI   SB   CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0    4  ...    0.0  0.0  0.0   0  0.0  NaN  NaN NaN NaN   NaN
# 1  118  ...   13.0  8.0  1.0   4  0.0  NaN  NaN NaN NaN   NaN
# 2  137  ...   19.0  3.0  1.0   2  5.0  NaN  NaN NaN NaN   NaN
# 3  133  ...   27.0  1.0  1.0   0  2.0  NaN  NaN NaN NaN   NaN
# 4  120  ...   16.0  6.0  2.0   2  1.0  NaN  NaN NaN NaN   NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Q2 Print out the dimensions and info about the dataframe you just created

# %%
df.shape
# Out:
# (102816, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102816 entries, 0 to 102815
# Data columns (total 25 columns):
# playerID     102816 non-null object
# nameFirst    102816 non-null object
# nameLast     102816 non-null object
# birthYear    102816 non-null int64
# yearID       102816 non-null int64
# stint        102816 non-null int64
# teamID       102816 non-null object
# lgID         102079 non-null object
# G            102816 non-null int64
# AB           102816 non-null int64
# R            102816 non-null int64
# H            102816 non-null int64
# 2B           102816 non-null int64
# 3B           102816 non-null int64
# HR           102816 non-null int64
# RBI          102392 non-null float64
# SB           101516 non-null float64
# CS           79360 non-null float64
# BB           102816 non-null int64
# SO           94978 non-null float64
# IBB          66251 non-null float64
# HBP          100006 non-null float64
# SH           96478 non-null float64
# ...

# %% [markdown]
# ### Q3 How many players have hit 40 or more HRs in one single season? (Number only)

# %%
x = df.groupby(['playerID', 'yearID'],as_index=False)[['HR']].sum()
x[x.HR >39]
x[x.HR >39]['playerID']
len(x[x.HR >39]['playerID'].unique())
# Out:
# 142

# %% [markdown]
# ### Q4 How many players have hit more than 600 HRs for their career? (Dataframe)

# %%
y = df.groupby(['playerID'],as_index=False).sum()
y[y.HR > 600].reset_index(drop=True)
# Out:
#     playerID  birthYear  yearID  stint     G     AB     R     H   2B   3B  \
# 0  aaronha01      44482   45195     23  3298  12364  2174  3771  624   98
# 1  bondsba01      43208   43923     22  2986   9847  2227  2935  601   77
# 2  griffke02      45287   45997     24  2671   9801  1662  2781  524   38
# 3   mayswi01      44413   45145     24  2992  10881  2062  3283  523  140
# 4  rodrial01      43450   44101     22  2784  10566  2021  3115  548   31
# 5   ruthba01      41690   42339     22  2503   8398  2174  2873  506  136
# 6   sosasa01      37392   37945     20  2354   8813  1475  2408  379   45
# 7  thomeji01      49250   50065     28  2543   8422  1583  2328  451   26
#
#    ...       RBI     SB     CS    BB      SO    IBB    HBP     SH     SF  \
# 0  ...    2297.0  240.0   73.0  1402  1383.0  293.0   32.0   21.0  121.0
# 1  ...    1996.0  514.0  141.0  2558  1539.0  688.0  106.0    4.0   91.0
# 2  ...    1836.0  184.0   69.0  1312  1779.0  246.0   81.0    8.0  102.0
# ...

# %% [markdown]
# ### Q5 How many players have hit 40 2Bs, 10 3Bs, 200 Hits, and 30 HRs (inclusive) in one season? (Number Only)

# %%
z = df.groupby(['playerID', 'yearID'],as_index=False)[['H','2B','3B','HR']].sum()
(z['2B'] > 39) & (z['3B'] > 9) & (z['H']>199) & (z['HR']>29)
a = z[(z['2B'] > 39) & (z['3B'] > 9) & (z['H']>199) & (z['HR']>29)]
a.playerID.unique()
len(a.playerID.unique())
# Out:
# 11

# %% [markdown]
# ### Q6 How many players have had 100 or more SBs in a season? (Dataframe)

# %%
b = df.groupby(['playerID', 'yearID'],as_index=False).sum()
b [b.SB > 100].reset_index(drop=True)
pd.DataFrame(b [b.SB > 100]['playerID'].unique(),columns=['playerID'])
# Out:
#      playerID
# 0   brocklo01
# 1   brownpe01
# 2   brownto01
# 3   colemvi01
# 4   comisch01
# 5   fogarji01
# 6   hamilbi01
# 7   henderi01
# 8   lathaar01
# 9   nicolhu01
# 10   wardjo01
# 11  willsma01

# %% [markdown]
# ### Q7 How many players in the 1960s have hit more than 200 HRs? (Dataframe)

# %%
(df.yearID > 1959) & (df.yearID < 1970)
c = df[(df.yearID > 1959) & (df.yearID < 1970)]
d = c.groupby(['playerID','nameFirst', 'nameLast'],as_index=False)[['HR']].sum()
d[d.HR>200].reset_index(drop=True)
# Out:
#      playerID nameFirst     nameLast   HR
# 0   aaronha01      Hank        Aaron  375
# 1   allisbo01       Bob      Allison  225
# 2   bankser01     Ernie        Banks  269
# 3    cashno01      Norm         Cash  278
# 4   cepedor01   Orlando       Cepeda  254
# 5   colavro01     Rocky     Colavito  245
# 6   howarfr01     Frank       Howard  288
# 7   kalinal01        Al       Kaline  210
# 8   killeha01    Harmon    Killebrew  393
# 9   mantlmi01    Mickey       Mantle  256
# 10  marisro01     Roger        Maris  217
# 11  matheed01     Eddie      Mathews  213
# 12   mayswi01    Willie         Mays  350
# 13  mccovwi01    Willie      McCovey  300
# 14  powelbo01      Boog       Powell  202
# 15  robinfr02     Frank     Robinson  316
# 16  santoro01       Ron        Santo  253
# 17  willibi01     Billy     Williams  249
# 18  yastrca01      Carl  Yastrzemski  202

# %% [markdown]
# ### Q8 Who has hit the most HRs in history? (Dataframe)

# %%
e = df.groupby(['playerID','nameFirst', 'nameLast'],as_index=False)[['HR']].sum()
e.sort_values(by=['HR'], ascending=[False]).head(1).reset_index(drop=True)
# Out:
#     playerID nameFirst nameLast   HR
# 0  bondsba01     Barry    Bonds  762

# %% [markdown]
# ### Q9 Who had the most hits in the 1970s? (Dataframe)

# %%
f = df[(df.yearID > 1969) & (df.yearID < 1980)]
g = f.groupby(['playerID','nameFirst', 'nameLast'],as_index=False)[['H']].sum()
g.sort_values(by=['H'], ascending=[False]).head(1).reset_index(drop=True)
# Out:
#    playerID nameFirst nameLast     H
# 0  rosepe01      Pete     Rose  2045

# %% [markdown]
# ### Q10 Top 5 highest OBP (on base percentage) with at least 500 PAs in 1977?  (Dataframe)

# %%
h = df.groupby(['yearID', 'playerID', 'nameFirst', 'nameLast'], as_index = False).sum()
h['OBP'] = (h['H'] + h['BB'] + h['IBB'] + h['SH'] + h['SF']) / h['AB']
h['PA'] = h['AB'] + h['BB'] + h['IBB'] + h['SH'] + h['SF']
h = h[(h['yearID'] == 1977) & (h['PA'] >= 500)]
h.sort_values(by=['OBP'], ascending=[False]).head().reset_index(drop=True)
# Out:
#    yearID   playerID nameFirst   nameLast  birthYear  stint    G   AB    R  \
# 0    1977  singlke01       Ken  Singleton       1947      1  152  536   90
# 1    1977  smithre06    Reggie      Smith       1945      1  148  488  104
# 2    1977  tenacge01      Gene     Tenace       1946      1  147  437   66
# 3    1977  hargrmi01      Mike   Hargrove       1949      1  153  525   98
# 4    1977  carewro01       Rod      Carew       1945      1  155  616  128
#
#      H  ...      CS   BB     SO   IBB   HBP   SH   SF  GIDP       OBP     PA
# 0  176  ...     1.0  107  101.0  13.0   2.0  0.0  6.0  15.0  0.563433  662.0
# 1  150  ...     5.0  104   76.0  11.0   3.0  1.0  7.0   5.0  0.559426  611.0
# 2  102  ...     3.0  125  119.0  10.0  13.0  2.0  4.0   5.0  0.556064  578.0
# 3  160  ...     5.0  103   59.0   7.0   6.0  8.0  6.0  13.0  0.540952  649.0
# 4  239  ...    13.0   69   55.0  15.0   3.0  1.0  5.0   6.0  0.534091  706.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Q11 Top 8 highest averages in 2013 with at least 300 PAs? (Dataframe)

# %%
i = df.groupby(['yearID', 'playerID', 'nameFirst', 'nameLast'], as_index = False).sum()
i['PA'] = i['AB'] + i['BB'] + i['IBB'] + i['SH'] + i['SF']
i['Average'] = i['H'] / i['AB']
i = i[(i['yearID'] == 2013) & (i['PA'] >= 300)]
i.sort_values(by=['Average'], ascending=[False]).head(8).reset_index(drop=True)
# Out:
#    yearID   playerID nameFirst nameLast  birthYear  stint    G   AB    R    H  \
# 0    2013  cabremi01    Miguel  Cabrera       1983      1  148  555  103  193
# 1    2013  ramirha01    Hanley  Ramirez       1983      1   86  304   62  105
# 2    2013  cuddymi01   Michael  Cuddyer       1979      1  130  489   74  162
# 3    2013  mauerjo01       Joe    Mauer       1983      1  113  445   62  144
# 4    2013  troutmi01      Mike    Trout       1991      1  157  589  109  190
# 5    2013  johnsch05     Chris  Johnson       1984      1  142  514   54  165
# 6    2013  freemfr01   Freddie  Freeman       1989      1  147  551   89  176
# 7    2013   puigya01    Yasiel     Puig       1990      1  104  382   66  122
#
#      ...      CS   BB     SO   IBB   HBP   SH   SF  GIDP     PA   Average
# 0    ...     0.0   90   94.0  19.0   5.0  0.0  2.0  19.0  666.0  0.347748
# 1    ...     2.0   27   52.0   3.0   3.0  0.0  2.0   5.0  336.0  0.345395
# ...

# %% [markdown]
# ### Q12 Leaders in hits from 1940 up to and including 1949. (Dataframe)

# %%
(df.yearID > 1939) & (df.yearID < 1950)
j = df[(df.yearID > 1939) & (df.yearID < 1950)]
k = j.groupby(['playerID','nameFirst', 'nameLast'],as_index=False)[['H']].sum()
k.sort_values(by=['H'], ascending=[False]).head(10).reset_index(drop=True)
# Out:
#     playerID nameFirst    nameLast     H
# 0  boudrlo01       Lou    Boudreau  1578
# 1  elliobo01       Bob     Elliott  1563
# 2  walkedi02     Dixie      Walker  1512
# 3  musiast01      Stan      Musial  1432
# 4  doerrbo01     Bobby       Doerr  1407
# 5  holmeto01     Tommy      Holmes  1402
# 6  applilu01      Luke     Appling  1376
# 7  nichobi01      Bill   Nicholson  1328
# 8  marioma01     Marty      Marion  1310
# 9  cavarph01      Phil  Cavarretta  1304

# %% [markdown]
# ### Q13 Who led MLB with the most hits the most times?  And how many times?  (Dataframe, Number)

# %%
l=df.groupby(['playerID','yearID','nameFirst', 'nameLast'],as_index=False)[['H']].sum()
l_max=l.groupby('yearID',as_index=False)[['H']].max()
m=pd.merge(l,l_max,on=['yearID','H'],how='right')
most_hits=m.groupby(['playerID','nameFirst', 'nameLast'],as_index=False)[['yearID']].count().sort_values(by=['yearID'],ascending=False)
print(most_hits[most_hits['yearID']==max(most_hits['yearID'])])
# Out:
#      playerID nameFirst nameLast  yearID
# 85  suzukic01    Ichiro   Suzuki       7
# 22   cobbty01        Ty     Cobb       7
# 75   rosepe01      Pete     Rose       7

# %% [markdown]
# ### Q14 Which players have played the most games for their careers?  Top 5, descending by games played presented as a dataframe

# %%
n=df.groupby(['playerID','nameFirst', 'nameLast'],as_index=False)[['G']].sum()
n.sort_values(by='G',ascending=False).head().reset_index(drop=True)
# Out:
#     playerID nameFirst     nameLast     G
# 0   rosepe01      Pete         Rose  3562
# 1  yastrca01      Carl  Yastrzemski  3308
# 2  aaronha01      Hank        Aaron  3298
# 3  henderi01    Rickey    Henderson  3081
# 4   cobbty01        Ty         Cobb  3035

# %% [markdown]
# ### Q15 How many players have had more than 3000 hits for their careers while also hitting 500 or more HRs?  Just a number is okay here

# %%
o = df.groupby(['playerID','nameFirst', 'nameLast'],as_index=False)[['H', 'HR']].sum()
len(o[(o.HR > 499) & (o.H > 3000)])
# Out:
# 5

# %% [markdown]
# ### Q16 How many HRs were hit during the entire 1988 season?  Just a number is okay here

# %%
df[df.yearID == 1988]['HR'].sum()
# Out:
# 3180

# %% [markdown]
# ### Q17 Please filter out and show me the top 3 average seasons by Wade Boggs during his career in seasons in which he had at least 500 ABs.  I would like a dataframe sorted by average.

# %%
i = df.groupby(['yearID', 'playerID', 'nameFirst', 'nameLast'], as_index = False).sum()
i['PA'] = i['AB'] + i['BB'] + i['IBB'] + i['SH'] + i['SF']
i['Average'] = i['H'] / i['AB']
p = i[(i.nameFirst == 'Wade') & (i.nameLast == 'Boggs')]
p[p.AB > 500].sort_values(by=['Average'], ascending=[False]).head(3).reset_index(drop=True)
# Out:
#    yearID   playerID nameFirst nameLast  birthYear  stint    G   AB    R    H  \
# 0    1985  boggswa01      Wade    Boggs       1958      1  161  653  107  240
# 1    1988  boggswa01      Wade    Boggs       1958      1  155  584  128  214
# 2    1987  boggswa01      Wade    Boggs       1958      1  147  551  108  200
#
#      ...      CS   BB    SO   IBB  HBP   SH   SF  GIDP     PA   Average
# 0    ...     1.0   96  61.0   5.0  4.0  3.0  2.0  20.0  759.0  0.367534
# 1    ...     3.0  125  34.0  18.0  3.0  0.0  7.0  23.0  734.0  0.366438
# 2    ...     3.0  105  48.0  19.0  2.0  1.0  8.0  13.0  684.0  0.362976
#
# [3 rows x 25 columns]

# %% [markdown]
# ### Q18 Please filter out the top OBPs for the 1995 season with at least 400 PAs, sorted by OBP.  I would like a dataframe for this

# %%
h = df.groupby(['yearID', 'playerID', 'nameFirst', 'nameLast'], as_index = False).sum()
h['OBP'] = (h['H'] + h['BB'] + h['IBB'] + h['SH'] + h['SF']) / h['AB']
h['PA'] = h['AB'] + h['BB'] + h['IBB'] + h['SH'] + h['SF']
q = h[(h['yearID'] == 1995) & (h['PA'] >= 400)]
q.sort_values(by=['OBP'], ascending=[False]).head(10).reset_index(drop=True)
# Out:
#    yearID   playerID nameFirst  nameLast  birthYear  stint    G   AB    R  \
# 0    1995  thomafr04     Frank    Thomas       1968      1  145  493  102
# 1    1995  martied01     Edgar  Martinez       1963      1  145  511  121
# 2    1995  mcgwima01      Mark   McGwire       1963      1  104  317   75
# 3    1995  bondsba01     Barry     Bonds       1964      1  144  506  109
# 4    1995  davisch01     Chili     Davis       1960      1  119  424   81
# 5    1995  magadda01      Dave   Magadan       1962      1  127  348   44
# 6    1995  thomeji01       Jim     Thome       1970      1  137  452   92
# 7    1995  baineha01    Harold    Baines       1959      1  127  385   60
# 8    1995  weisswa01      Walt     Weiss       1963      1  137  427   65
# 9    1995  boggswa01      Wade     Boggs       1958      1  126  460   76
#
#      H  ...      CS   BB     SO   IBB   HBP   SH    SF  GIDP       OBP     PA
# ...

# %% [markdown]
# ### Q19 Who had the most 3Bs (in total) in 1922, 1925, 1926, and 1928?  I would like a dataframe with just the leader

# %% [markdown]
# #### Since the language of the question is not clear, I have done the question in two ways

# %%
df[(df['yearID'] == 1922) | (df['yearID'] == 1925) | (df['yearID'] == 1926) | (df['yearID'] == 1928)].groupby(['playerID', 'nameFirst', 'nameLast'], as_index = False).sum().sort_values(by = '3B', ascending = False).head(1)
# Out:
#        playerID nameFirst nameLast  birthYear  yearID  stint    G    AB    R  \
# 1011  walkecu01      Curt   Walker       7584    7701      4  571  2088  335
#
#         H  ...     RBI    SB    CS   BB     SO  IBB  HBP    SH   SF  GIDP
# 1011  652  ...   311.0  47.0  15.0  222  122.0  0.0  5.0  81.0  0.0   0.0
#
# [1 rows x 23 columns]

# %%
df1=df.groupby(['playerID','nameFirst','nameLast','yearID'],as_index=False).sum() 
df1['PA']= df1['AB']+df1['BB']+df1['IBB']+df1['SF']+df1['SH']
df1['Average']= df1['H']/df1['AB'] 
df1['OBP']= (df1['H']+df1['BB']+df1['IBB']+df1['SH']+df1['SF']) /df1['AB'] 
max3BIn1922 = df1[df1['yearID']==1922][['yearID','playerID','nameFirst','nameLast','3B']].sort_values('3B',ascending=False).head(1) 
max3BIn1925 = df1[df1['yearID']==1925][['yearID','playerID','nameFirst','nameLast','3B']].sort_values('3B',ascending=False).head(1) 
max3BIn1926 = df1[df1['yearID']==1926][['yearID','playerID','nameFirst','nameLast','3B']].sort_values('3B',ascending=False).head(1) 
max3BIn1928 = df1[df1['yearID']==1928][['yearID','playerID','nameFirst','nameLast','3B']].sort_values('3B',ascending=False).head(1) 
pd.concat([max3BIn1922,max3BIn1925,max3BIn1926,max3BIn1928]).reset_index(drop=True)
# Out:
#    yearID   playerID nameFirst nameLast  3B
# 0    1922  daubeja01      Jake  Daubert  22
# 1    1925  cuyleki01      Kiki   Cuyler  26
# 2    1926  wanerpa01      Paul    Waner  22
# 3    1928  combsea01     Earle    Combs  21

# %% [markdown]
# ### Q20 How many players have hit 30 or more HRs in season while also stealing (SB) 30 more or bases?  A number is okay here

# %%
r = df.groupby(['playerID', 'yearID'],as_index=False)[['HR','SB']].sum()
r[(r.HR > 29) & (r.SB > 29)]['playerID']
len(r[(r.HR > 29) & (r.SB > 29)]['playerID'].unique())
# Out:
# 38

# %% [markdown]
# ### Q21 Who had the highest OBP is 1986 with at least 400 PAs? (Dataframe)

# %%
h = df.groupby(['yearID', 'playerID', 'nameFirst', 'nameLast'], as_index = False).sum()
h['OBP'] = (h['H'] + h['BB'] + h['IBB'] + h['SH'] + h['SF']) / h['AB']
h['PA'] = h['AB'] + h['BB'] + h['IBB'] + h['SH'] + h['SF']
s = h.groupby(['yearID', 'playerID', 'nameFirst', 'nameLast'], as_index = False)[['PA','OBP']].sum()
s[(s.yearID == 1986) & (s.PA > 399)].sort_values(by=['OBP'], ascending=[False]).head(1)
# Out:
#        yearID   playerID nameFirst nameLast     PA       OBP
# 58869    1986  boggswa01      Wade    Boggs  707.0  0.575862

# %% [markdown]
# ### Q22 Same question but for 1997 and only in the NL (check league ID)? (Dataframe)

# %%
h = df.groupby(['yearID', 'playerID', 'nameFirst', 'nameLast','lgID'], as_index = False).sum()
h['OBP'] = (h['H'] + h['BB'] + h['IBB'] + h['SH'] + h['SF']) / h['AB']
h['PA'] = h['AB'] + h['BB'] + h['IBB'] + h['SH'] + h['SF']
s = h.groupby(['yearID', 'playerID', 'nameFirst', 'nameLast','lgID'], as_index = False)[['PA','OBP']].sum()
s[(s.yearID == 1997) & (s.PA > 399) & (s.lgID == 'NL')].sort_values(by=['OBP'], ascending=[False]).head(1)
# Out:
#        yearID   playerID nameFirst nameLast lgID     PA       OBP
# 70967    1997  bondsba01     Barry    Bonds   NL  716.0  0.637218

# %% [markdown]
# ### Q23 Who had more than the league average HRs in 2012 (filter out all players with less 500 PAs)? (Dataframe)

# %%
df1= df[df['yearID']==2012].groupby(['playerID','nameFirst','nameLast','yearID'],as_index=False ).sum()
df1['PA']= df1['AB']+df1['BB']+df1['IBB']+df1['SF']+df1['SH']
df1[(df1['PA']>=500) & (df1['HR']> df1['HR'].mean())][['playerID','nameFirst','nameLast','yearID','HR']].sort_values('HR',ascending=False).reset_index(drop=True)
# Out:
#       playerID  nameFirst     nameLast  yearID  HR
# 0    cabremi01     Miguel      Cabrera    2012  44
# 1    grandcu01     Curtis   Granderson    2012  43
# 2    hamiljo03       Josh     Hamilton    2012  43
# 3    encared01      Edwin  Encarnacion    2012  42
# 4     dunnad01       Adam         Dunn    2012  41
# 5    braunry02       Ryan        Braun    2012  41
# 6    stantmi03  Giancarlo      Stanton    2012  37
# 7    beltrad01     Adrian       Beltre    2012  36
# 8    willijo03       Josh   Willingham    2012  35
# 9    bruceja01        Jay        Bruce    2012  34
# 10   davisch02      Chris        Davis    2012  33
# 11    canoro01   Robinson         Cano    2012  33
# 12   larocad01       Adam      LaRoche    2012  33
# 13   davisik02        Ike        Davis    2012  32
# 14   trumbma01       Mark       Trumbo    2012  32
# 15   soriaal01    Alfonso      Soriano    2012  32
# 16   reddijo01       Josh      Reddick    2012  32
# ...

# %% [markdown]
# ### Q24 Who is the youngest player to hit 50 or more HRs in a single season? (Dataframe)

# %%
v= df.groupby(['yearID', 'birthYear', 'playerID', 'nameFirst', 'nameLast'], as_index = False).sum()
v['Age'] = v['yearID'] - v['birthYear']
v[v['HR'] >= 50].sort_values(by = 'Age', ascending = True).head(1)
# Out:
#        yearID  birthYear   playerID nameFirst nameLast  stint    G   AB    R  \
# 83459    2007       1984  fieldpr01    Prince  Fielder      1  158  573  109
#
#          H ...    SB   CS  BB     SO   IBB   HBP   SH   SF  GIDP  Age
# 83459  165 ...   2.0  2.0  90  121.0  21.0  14.0  0.0  4.0   9.0   23
#
# [1 rows x 24 columns]

# %% [markdown]
# ### Q25 Who are the five youngest players to hit 300 or more HRs for their career? (Dataframe)

# %%
w = df.groupby(['playerID', 'nameFirst', 'nameLast', 'birthYear', 'yearID']).sum().groupby(level=0).cumsum().reset_index()
w = w[w['HR'] >= 300].sort_values(by = ['yearID', 'birthYear', 'playerID'])[['playerID', 'nameFirst', 'nameLast', 'birthYear', 'yearID', 'HR']]
w['Age'] = w['yearID'] - w['birthYear']
w.sort_values(by = 'Age', ascending = True).head()
# Out:
#         playerID nameFirst   nameLast  birthYear  yearID   HR  Age
# 69369  pujolal01    Albert     Pujols       1980    2008  319   28
# 64767    ottme01       Mel        Ott       1909    1937  306   28
# 43074  jonesan01    Andruw      Jones       1977    2005  301   28
# 27852   foxxji01    Jimmie       Foxx       1907    1935  302   28
# 73216  rodrial01      Alex  Rodriguez       1975    2003  345   28

# %% [markdown]
# # Bonus Questions

# %%
import matplotlib.pyplot as plt
#plt.style.use('bmh')
#plt.style.use('fivethirtyeight')

# %% [markdown]
# ### (1) Graph total HRs per season using bar graph

# %%
df.dropna()
# %matplotlib inline
plt.style.use('seaborn-bright')
df1 = df.groupby('yearID').sum()['HR'].reset_index()
plt.figure(figsize = (15, 5))
plt.bar(df1.yearID,df1.HR, align='center', alpha= 0.8)
plt.ylabel('Home Runs')
plt.xlabel('Years')
plt.title('Home Runs scored per season')
plt.show()

# %%
df.dropna()
# %matplotlib inline
plt.style.use('ggplot')
df1 = df.groupby('yearID').sum()['HR'].reset_index()
plt.figure(figsize = (15, 5))
plt.bar(df1.yearID,df1.HR, align='center', alpha= 0.8)
plt.ylabel('Home Runs')
plt.xlabel('Years')
plt.title('Home Runs scored per season')
plt.show()

# %%
df.dropna()
# %matplotlib inline
plt.style.use('dark_background')
df1 = df.groupby('yearID').sum()['HR'].reset_index()
plt.figure(figsize = (15, 5))
plt.bar(df1.yearID,df1.HR, align='center', alpha= 0.8)
plt.ylabel('Home Runs')
plt.xlabel('Years')
plt.title('Home Runs scored per season')
plt.show()

# %% [markdown]
# ### (2) Using a line graph please graph the average HRs per AB (think about this) per season

# %%
plt.style.use('seaborn-bright')
df1 = df[df['HR']>=0].groupby('yearID').mean()['HR']
df2 = df[df['AB']>=0].groupby('yearID').mean()['AB']
df3 = df1/df2
df3.plot.line(x=df1.index,y=df2,figsize=(15,4),lw=1)
plt.ylabel('Average HRs per AB')
plt.xlabel('Years')
plt.title('Year v/s Average, Home Runs (HRs) per At-bat(AB)')
plt.show()

# %%
plt.style.use('ggplot')
df1 = df[df['HR']>=0].groupby('yearID').mean()['HR']
df2 = df[df['AB']>=0].groupby('yearID').mean()['AB']
df3 = df1/df2
df3.plot.line(x=df1.index,y=df2,figsize=(15,4),lw=1)
plt.ylabel('Average HRs per AB')
plt.xlabel('Years')
plt.title('Year v/s Average, Home Runs (HRs) per At-bat(AB)')
plt.show()

# %%
plt.style.use('dark_background')
df1 = df[df['HR']>=0].groupby('yearID').mean()['HR']
df2 = df[df['AB']>=0].groupby('yearID').mean()['AB']
df3 = df1/df2
df3.plot.line(x=df1.index,y=df2,figsize=(15,4),lw=1,alpha= 0.99)
plt.ylabel('Average HRs per AB')
plt.xlabel('Years')
plt.title('Year v/s Average, Home Runs (HRs) per At-bat(AB)')
plt.show()
